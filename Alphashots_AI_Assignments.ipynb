# %% [markdown]
# <a href="https://colab.research.google.com/github/mrudulamadhavan/My-Projects/blob/main/Alphashots_AI_Assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **AlphaShots.AI Assignment**

# %% [markdown]
# ## **Assignment 1**
#
# 1) Login to alphashots.ai, Query a stock/Indices with a holding period and click submit to get AI generated results.
#
# 2) Analyse AI results shown in next page ( https://www.alphashots.ai/result-calculation).
#
# 3) Write only 3-4 sentences of which algorithm/Machine learning is used by alphashots.ai to predict the historical patterns?
#
#  **Answer**
#
# AlphaShots.AI relies on machine learning technologies, including time series analysis and regression models, to perform stock pattern recognition of time series data. While time series analysis provides information about stock price trends and fluctuations, regression techniques show how stock price depends on the amount of trade and other determined parameters.Depending on the data's nature, it may employ linear regression, polynomial regression, or more sophisticated forms like logistic regression.
#
#  For looking forward, the platform implements neural network algorithms, focusing on RNNs and LSTMs. Other ensemble models like Random Forests and Gradient Boosting improve the efficiency of the models by averaging the estimated outcomes from different models. The combination of these techniques facilitates AlphaShots.AI to identify investment opportunities by explaining patterns in the past data and trends.
#
# - Linear Regression: Effective for predicting continuous values, such as stock prices.
#
# - Support Vector Machines (SVM): Suitable for both classification and regression tasks, SVMs can capture nonlinear relationships in the data.
#
# - Recurrent Neural Networks (RNNs): Particularly well-suited for sequential data, RNNs can capture temporal dependencies in stock price movements.
#
# - Long Short-Term Memory (LSTM) Networks: A type of RNN designed to address the vanishing gradient problem, LSTMs are widely used for time series prediction tasks.

# %% [markdown]
# ## **Assignment 2**
#
# # **Alphashots.AI Currency Analysis**

# %% [markdown]
# 1. Scrape the EUR/INR currency data from Yahoo Finance, covering the period from January 1, 2023, to sept 30, 2024.
# 2. Conduct a technical analysis and calculate the following metrics for one day and one week from Sept 30,2024
# - Moving Average
# - Bollinger Band
# - CCI (Commodity Channel Index)
#
# Note: Please consult various online sources to understand how to perform technical analysis on the currency market.
# 3. Based on the results of the technical indicators, make a decision to BUY, SELL or remain NEUTRAL for the specified time frames.

# %% [markdown]
# ### **Code Implementation**

# %%
# !pip install yahoo_fin

# %%
# importing necessary libraries

import numpy as np
import pandas as pd
from yahoo_fin.stock_info import get_data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
ticker = 'EURINR=X'
start='2023-01-01'
end='2024-09-30'
data = get_data(ticker, start_date = start, end_date = end, index_as_date = True, interval = '1d')
data = pd.DataFrame(data)

# %%
data
# Out:
#                  open       high        low      close   adjclose  volume  \
# 2023-01-02  87.157700  88.400002  87.157700  88.482002  88.482002       0
# 2023-01-03  88.292000  88.313004  87.225998  88.300003  88.300003       0
# 2023-01-04  87.219002  87.922997  87.219002  87.219002  87.219002       0
# 2023-01-05  87.580002  87.807999  86.757004  87.605003  87.605003       0
# 2023-01-06  86.819000  87.614998  86.647003  86.827003  86.827003       0
# ...               ...        ...        ...        ...        ...     ...
# 2024-09-23  92.775002  93.248001  92.671997  92.753998  92.753998       0
# 2024-09-24  93.490997  93.627998  93.083000  93.438004  93.438004       0
# 2024-09-25  92.995003  93.467003  92.994003  93.000999  93.000999       0
# 2024-09-26  93.371002  93.629997  93.037003  93.367996  93.367996       0
# 2024-09-29  92.414001  93.839996  92.414001  93.369003  93.369003       0
#
#               ticker
# 2023-01-02  EURINR=X
# 2023-01-03  EURINR=X
# ...

# %%
data.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'adjclose', 'volume', 'ticker'], dtype='object')

# %%
# Saving the data to a CSV file
data.to_csv('EUR_INR_data.csv')

# %%
data_new = data.copy()
data_new['Date']  = data_new.index
data_new = data_new[['Date','open', 'high', 'low', 'close', 'adjclose', 'volume']]
data_new. reset_index(drop=True)

data_new.head()
# Out:
#                  Date       open       high        low      close   adjclose  \
# 2023-01-02 2023-01-02  87.157700  88.400002  87.157700  88.482002  88.482002
# 2023-01-03 2023-01-03  88.292000  88.313004  87.225998  88.300003  88.300003
# 2023-01-04 2023-01-04  87.219002  87.922997  87.219002  87.219002  87.219002
# 2023-01-05 2023-01-05  87.580002  87.807999  86.757004  87.605003  87.605003
# 2023-01-06 2023-01-06  86.819000  87.614998  86.647003  86.827003  86.827003
#
#             volume
# 2023-01-02       0
# 2023-01-03       0
# 2023-01-04       0
# 2023-01-05       0
# 2023-01-06       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 456 entries, 2023-01-02 to 2024-09-29
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   open      456 non-null    float64
#  1   high      456 non-null    float64
#  2   low       456 non-null    float64
#  3   close     456 non-null    float64
#  4   adjclose  456 non-null    float64
#  5   volume    456 non-null    int64
#  6   ticker    456 non-null    object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 28.5+ KB

# %% [markdown]
# No missing values in the dataset.

# %% [markdown]
# Let’s examine the columns in detail for further analysis:
#
# * The “Open” and “Close” columns show the opening and closing prices of the stocks on a specific day.
# * The “High” and “Low” columns indicate the highest and lowest prices reached by the stock on a particular day, respectively.
# * The “Volume” column provides information about the total volume of stocks traded on a specific day.
# * The “Adj_Close” column represents the adjusted closing price, which reflects the stock’s closing price on any given trading day, considering factors such as dividends, stock splits, or other corporate actions.

# %%
data.drop("ticker",inplace = True,axis = 1)

# %%
data.describe()
# Out:
#              open        high         low       close    adjclose  volume
# count  456.000000  456.000000  456.000000  456.000000  456.000000   456.0
# mean    89.623414   90.059415   89.396986   89.728670   89.728670     0.0
# std      1.491535    1.418949    1.482412    1.428623    1.428623     0.0
# min     85.691902   86.615997   85.691902   86.383003   86.383003     0.0
# 25%     88.656498   89.082251   88.431000   88.788000   88.788000     0.0
# 50%     89.560001   90.005001   89.386002   89.623501   89.623501     0.0
# 75%     90.443251   90.795502   90.197250   90.457003   90.457003     0.0
# max     93.700996   93.839996   93.504997   93.722000   93.722000     0.0

# %%
figure = px.line(data_new,x = 'Date',y="close", title='EUR - INR Conversion Rate over the years')
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data_new["Date"] = pd.to_datetime(data_new["Date"], format = '%Y-%m-%d')
data_new['Year'] = data_new['Date'].dt.year
data_new["Month"] = data_new["Date"].dt.month

# %%
import plotly.graph_objs as go
import plotly.io as pio


# Calculate monthly growth
data_new['Growth'] = data_new.groupby(['Year', 'Month'])['close'].transform(lambda x: (x.iloc[-1] - x.iloc[0]) / x.iloc[0] * 100)

# Group data by Month and calculate average growth
grouped_data = data_new.groupby('Month').mean().reset_index()

fig = go.Figure()

fig.add_trace(go.Bar(
    x=grouped_data['Month'],
    y=grouped_data['Growth'],
    marker_color=grouped_data['Growth'],
    hovertemplate='Month: %{x}<br>Average Growth: %{y:.2f}%<extra></extra>'
))

fig.update_layout(
    title="Aggregated Monthly Growth of EUR - INR Conversion Rate",
    xaxis_title="Month",
    yaxis_title="Average Growth (%)",
    width=900,
    height=600
)

pio.show(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# In the above graph, we can see that the value of EUR always falls in January and February, while in the second quarter, EUR becomes stronger against INR every year, the value of EUR against INR peaks in July, but again falls in September, while in the last quarter, EUR becomes stronger against INR every year.

# %%
data['open'].plot(figsize=(15,6),c='g')
# data['close'].plot()
plt.title("EUR/INR Open Stock Price Trend")
plt.legend()
plt.show()

# %%
data['close'].plot(figsize=(15,6),c='r')
plt.title("EUR/INR Close Stock Price Trend")
plt.legend()
plt.show()

# %%
data['high'].plot(figsize=(15,6),c='y')
plt.title("EUR/INR High Stock Price Trend")
plt.legend()
plt.show()

# %%
data['low'].plot(figsize=(15,6),c='b')
plt.title("EUR/INR Low Stock Price Trend")
plt.legend()
plt.show()

# %%
# Moving Average
data['MA_7'] = data['close'].rolling(window=7).mean()
data['MA_30'] = data['close'].rolling(window=30).mean()
data['MA_50'] = data['close'].rolling(window=50).mean()
data['close'].plot(figsize=(15,5))
data['MA_7'].plot(c='r')
data['MA_30'].plot(c = 'g')
plt.title("EUR/INR Stock Prices - Moving Average")
plt.legend()
plt.show()

# %% [markdown]
# **Bollinger Bands**
#
# - Bollinger Bands is a technical analysis tool used to determine where prices are high and low relative to each other. These bands are composed of three lines: a simple moving average (the middle band) and an upper and lower band.
#
# - The upper and lower bands are typically two standard deviations above or below a 20-period simple moving average (SMA).
# The bands widen and narrow as the volatility of the underlying asset changes.
#
# First, calculate a simple moving average. Next, calculate the standard deviation over the same number of periods as the simple moving average. For the upper band, add the standard deviation to the moving average. For the lower band, subtract the standard deviation from the moving average.

# %%
# Bollinger Bands
data['MA_20'] = data['close'].rolling(window=20).mean()
data['STD_20'] = data['close'].rolling(window=20).std()
data['Upper_Band'] = data['MA_20'] + (2 * data['STD_20'])
data['Lower_Band'] = data['MA_20'] - (2 * data['STD_20'])

# %%
data['close'].plot(figsize=(15,5))
data['Lower_Band'].plot(c='pink')
data['MA_20'].plot(c='r')
data['Upper_Band'].plot(c='y')
plt.fill_between(data.index, data['Upper_Band'], data['Lower_Band'], alpha=0.2, label='Bollinger Bands')
plt.title("EUR/INR Stock Prices - Bollinger Bands")
plt.legend()
plt.show()

# %% [markdown]
# **Commodity Channel Index**
#
# - The Commodity Channel Index (CCI) is a technical indicator that measures the difference between the current price and the historical average price.
# - When the CCI is above zero, it indicates the price is above the historic average. Conversely, when the CCI is below zero, the price is below the historic average.
# - The CCI is an unbounded oscillator, meaning it can go higher or lower indefinitely. For this reason, overbought and oversold levels are typically determined for each individual asset by looking at historical extreme CCI levels where the price reversed from.
#
# >> ![image.png](data:image/png;base64,...)

# %%
# CCI
data['Typical_Price'] = (data['high'] + data['low'] + data['close']) / 3
data['Moving_Average'] = data['Typical_Price'].rolling(window=20).mean()
mean_deviation = lambda x: np.mean(np.abs(x - x.mean()))
data['Mean_Deviation'] = data['Typical_Price'].rolling(window=20).apply(mean_deviation)
data['CCI'] = (data['Typical_Price'] - data['Moving_Average']) / (.015 * data['Mean_Deviation'])

# %%
data['Typical_Price'].plot(figsize=(15,5))
data['CCI'].plot(c='r')
plt.title("EUR/INR Stock Prices - Commodity Channel Index")
plt.legend()
plt.show()

# %% [markdown]
# **Relative Strength Index (RSI)**
#
# The Relative Strength Index (RSI) is a momentum oscillator that measures the speed and change of price movements. It oscillates between 0 and 100.
#
#  Typically, values above 70 indicate overbought conditions, while values below 30 indicate oversold conditions.
#
# To find RSI,
#
# - Calculate the difference between consecutive closing prices.
# - Separate Gains and Losses by identifying periods of price increases (gains) and decreases (losses).
# - Calculate the Exponential Moving Averages (EMA) of gains and losses over the specified period.
# - Calculate Relative Strength (RS) by dividing the EMA of gains by the EMA of losses.
# - Calculate RSI:
#
# **RSI = 100 - (100 / (1 + RS))**

# %%
def calculate_rsi(data, period=14):
  """
  Calculates the Relative Strength Index (RSI)

  """

  delta = data['close'].diff()
  gain = delta.where(delta > 0, 0)
  loss = -delta.where(delta < 0, 0)

  # Calculate exponential moving averages of gains and losses
  exp1 = gain.ewm(com=period - 1, adjust=False).mean()
  exp2 = loss.ewm(com=period - 1, adjust=False).mean()

  RS = exp1 / exp2
  RSI = 100 - (100 / (1 + RS))

  return RSI


data['RSI'] = calculate_rsi(data, period=14)

# %%
# Decision Making
def decision_logic(current_data):
    if current_data['CCI'] > 100:
        return 'Sell'
    elif current_data['CCI'] < -100:
        return 'Buy'
    else:
        return 'Neutral'

# %%
data = data[['open','high', 'low', 'close', 'adjclose', 'volume','Typical_Price', 'MA_7', 'MA_20','MA_30',
       'MA_50',  'Upper_Band', 'Lower_Band', 'CCI', 'RSI']]

# %% [markdown]
# **Analyzing for specific dates**

# %%
# One day ahead date (Oct 1, 2024)
one_day_ahead = '2024-01-10'
day_data = data.loc[one_day_ahead]
day_data.T
# Out:
# open             90.844002
# high             90.988998
# low              90.667999
# close            90.803001
# adjclose         90.803001
# volume            0.000000
# Typical_Price    90.820000
# MA_7             90.804672
# MA_20            90.996485
# MA_30            90.658407
# MA_50            90.306412
# Upper_Band       92.208050
# Lower_Band       89.784921
# CCI             -55.493530
# RSI              50.675329
# Name: 2024-01-10 00:00:00, dtype: float64

# %%
# One week ahead date (Oct 7, 2024)
one_week_ahead = '2024-07-10'
week_data = data.loc[one_week_ahead]
week_data.T
# Out:
# open              90.375999
# high              90.919998
# low               89.379997
# close             90.371002
# adjclose          90.371002
# volume             0.000000
# Typical_Price     90.223666
# MA_7              90.021429
# MA_20             89.519640
# MA_30             89.780534
# MA_50             89.813246
# Upper_Band        90.643224
# Lower_Band        88.396056
# CCI              118.014488
# RSI               55.700559
# Name: 2024-07-10 00:00:00, dtype: float64

# %%
# Making decisions
decision_today = decision_logic(day_data)
decision_one_week = decision_logic(week_data)

# %%
print("Decision for", one_day_ahead, ":", decision_today)
# Out:
# Decision for 2024-01-10 : Neutral

# %%
print("Decision for", one_week_ahead, ":", decision_one_week)
# Out:
# Decision for 2024-07-10 : Sell

# %% [markdown]
# **Decision Table**

# %%
def make_decision(row):
    if row['MA_7'] > row['MA_30'] and row['RSI'] < 30:
        return 'Buy'
    elif row['MA_7'] < row['MA_30'] and row['RSI'] > 70:
        return 'Sell'
    elif row['Typical_Price'] > row['Upper_Band']:
        return 'Sell'
    elif row['Typical_Price'] < row['Lower_Band']:
        return 'Buy'
    elif row['CCI'] > 100:
        return 'Sell'
    elif row['CCI'] < -100:
        return 'Buy'
    else:
        return 'Neutral'


data['Decision'] = data.apply(make_decision, axis=1)

# %%
dat = data.copy()
dat.drop(['MA_20','MA_50'],axis = 1,inplace = True)

# %%
dat.tail(10).round(3)
# Out:
#               open    high     low   close  adjclose  volume  Typical_Price  \
# 2024-09-16  93.289  93.298  93.041  93.264    93.264       0         93.201
# 2024-09-17  93.091  93.191  92.891  93.104    93.104       0         93.062
# 2024-09-18  92.935  93.459  92.611  92.928    92.928       0         92.999
# 2024-09-19  93.220  93.315  92.923  93.208    93.208       0         93.149
# 2024-09-22  92.267  93.202  92.267  93.110    93.110       0         92.860
# 2024-09-23  92.775  93.248  92.672  92.754    92.754       0         92.891
# 2024-09-24  93.491  93.628  93.083  93.438    93.438       0         93.383
# 2024-09-25  92.995  93.467  92.994  93.001    93.001       0         93.154
# 2024-09-26  93.371  93.630  93.037  93.368    93.368       0         93.345
# 2024-09-29  92.414  93.840  92.414  93.369    93.369       0         93.208
#
#               MA_7   MA_30  Upper_Band  Lower_Band      CCI     RSI Decision
# ...

# %%
# Assuming 'one_day_decisions' and 'one_week_decisions' are dictionaries containing the decisions for each indicator

decision = {'Indicator': ['MA_7', 'MA_30', 'Upper_Band', 'Lower_Band', 'CCI'],
        'One-Day_Decision': ['BUY', 'SELL', 'NEUTRAL', 'BUY', 'NEUTRAL'],
        'One-Week_Decision': ['NEUTRAL', 'SELL', 'BUY', 'NEUTRAL', 'SELL']}



decision_table = pd.DataFrame({ 'Indicator': ['MA_7', 'MA_30', 'Upper_Band', 'Lower_Band', 'CCI'],
    'One-Day Decision': [decision['One-Day_Decision'][0],  # Accessing the first element
        decision['One-Day_Decision'][1],
        decision['One-Day_Decision'][2],
        decision['One-Day_Decision'][3],
        decision['One-Day_Decision'][4]
    ],
    'One-Week Decision': [decision['One-Week_Decision'][0],
        decision['One-Week_Decision'][1],
        decision['One-Week_Decision'][2],
        decision['One-Week_Decision'][3],
        decision['One-Week_Decision'][4]
    ]
})

decision_table
# Out:
#     Indicator One-Day Decision One-Week Decision
# 0        MA_7              BUY           NEUTRAL
# 1       MA_30             SELL              SELL
# 2  Upper_Band          NEUTRAL               BUY
# 3  Lower_Band              BUY           NEUTRAL
# 4         CCI          NEUTRAL              SELL

# %%
fig, ax = plt.subplots()
ax.axis('tight')
ax.axis('off')
ax.table(cellText=decision_table.values, colLabels=decision_table.columns, loc='best')
plt.show()

# %% [markdown]
# ### **Conclusions :**
# * **Decision Logic Application:** The decision-making logic is applied to the dataset using indicators such as MA_7, MA_30, RSI, Typical Price, Upper Band, Lower Band, and CCI. The logic effectively categorizes the data into 'Buy', 'Sell', or 'Neutral' based on the specified conditions.
#
# * **Indicator Importance:** The use of multiple indicators ensures a comprehensive analysis, taking into account both trend and momentum indicators (MA, RSI) as well as volatility (Bollinger Bands) and market sentiment (CCI). This multi-faceted approach helps in making more informed trading decisions.

# %% [markdown]
# ### **By : Mrudula A P**
